# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv( 'D:\\КУРСЫ DATA SCIENCE\\МОИ ЗАДАЧКИ\\genome_matrix.csv', index_col=0)
df
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(df, cmap="viridis") # ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df_dota = pd.read_csv( 'D:\\КУРСЫ DATA SCIENCE\\МОИ ЗАДАЧКИ\\dota_hero_stats.csv')
df_dota
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
df_dota.mode( ) # Если что, то самое часто встречающееся - это "мода", в датафрейме функция .mode()
# Out:
#      Unnamed: 0 attack_type   id  legs      localized_name  \
# 0             0      Ranged    1   2.0             Abaddon
# 1             1         NaN    2   NaN           Alchemist
# 2             2         NaN    3   NaN  Ancient Apparition
# 3             3         NaN    4   NaN           Anti-Mage
# 4             4         NaN    5   NaN          Arc Warden
# ..          ...         ...  ...   ...                 ...
# 112         112         NaN  114   NaN          Windranger
# 113         113         NaN  119   NaN       Winter Wyvern
# 114         114         NaN  120   NaN        Witch Doctor
# 115         115         NaN  121   NaN         Wraith King
# 116         116         NaN  129   NaN                Zeus
#
#                                  name primary_attr  \
# 0               npc_dota_hero_abaddon          int
# 1     npc_dota_hero_abyssal_underlord          NaN
# 2             npc_dota_hero_alchemist          NaN
# ...

# %%
df_dota['roles'].str.split(",").str.len().value_counts() # лучше вот так,  str.split(",") -  список слов, str.len() - длинна списка, value_counts()  - подсчет
# Out:
# 4    38
# 5    33
# 3    28
# 2     9
# 6     8
# 1     1
# Name: roles, dtype: int64
