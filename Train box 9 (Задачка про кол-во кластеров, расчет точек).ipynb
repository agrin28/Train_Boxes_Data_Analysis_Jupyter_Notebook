# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv( 'D:\\КУРСЫ DATA SCIENCE\\МОИ ЗАДАЧКИ\\dataset_209770_6.txt', sep = " ")
df
# Out:
#               x            y
# 0   1497.574570  1489.564183
# 1    200.899981  1404.767479
# 2    291.896899   117.569465
# 3   1496.288533  1497.696001
# 4   1100.975155   594.844488
# ..          ...          ...
# 65   303.627038   106.066897
# 66   310.732298   113.722983
# 67  1099.258833   611.536157
# 68  1001.590847   702.200963
# 69   100.847333  1193.161162
#
# [70 rows x 2 columns]

# %%
data=pd.read_clipboard('dataset_209770_6.txt') # новый способ импортировать дата сет
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1]
# Index: []

# %%
df.plot.scatter ( x = 'x', y = 'y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df = pd.read_csv('D:\\КУРСЫ DATA SCIENCE\\МОИ ЗАДАЧКИ\\dataset_209770_6.txt', sep=' ', header=None) # пример решения с сайта
sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])
# Out:
# C:\Program Files (x86)\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='0', ylabel='1'>
